# %%
#introduction
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv('c:\\Users\\hoan\\Downloads\\JC-201810-citibike-tripdata.csv\\JC-201810-citibike-tripdata.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39138 entries, 0 to 39137
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             39138 non-null  int64
#  1   starttime                39138 non-null  object
#  2   stoptime                 39138 non-null  object
#  3   start station id         39138 non-null  int64
#  4   start station name       39138 non-null  object
#  5   start station latitude   39138 non-null  float64
#  6   start station longitude  39138 non-null  float64
#  7   end station id           39138 non-null  int64
#  8   end station name         39138 non-null  object
#  9   end station latitude     39138 non-null  float64
#  10  end station longitude    39138 non-null  float64
#  11  bikeid                   39138 non-null  int64
#  12  usertype                 39138 non-null  object
#  13  birth year               39138 non-null  int64
#  14  gender                   39138 non-null  int64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 4.5+ MB

# %%
df.sample()
# Out:
#        tripduration                 starttime                  stoptime  \
# 26400           279  2018-10-05 11:30:38.6510  2018-10-05 11:35:18.5130
#
#        start station id start station name  start station latitude  \
# 26400              3269    Brunswick & 6th               40.726012
#
#        start station longitude  end station id end station name  \
# 26400               -74.050389            3273     Manila & 1st
#
#        end station latitude  end station longitude  bikeid    usertype  \
# 26400             40.721651             -74.042884   29666  Subscriber
#
#        birth year  gender
# 26400        1993       2

# %%
#find top 5 most popular start station
top5_start= df['start station name'].value_counts()[:5]
print(top5_start)
# Out:
# start station name
# Grove St PATH     4752
# Hamilton Park     2283
# Exchange Place    2221
# Sip Ave           1809
# Harborside        1461
# Name: count, dtype: int64

# %%
#bar chart : 5 most popular start station in oct 2019
plt.bar(top5_start.index, top5_start.values)
plt.ylabel('total rentals')
plt.title('5 most popular start station in Oct, 2019')
plt.xticks(rotation= 15)
plt.show()

# %%
#find top 5 most popular end stations
top5_end = df['end station name'].value_counts()[:5]
print(top5_end)
# Out:
# end station name
# Grove St PATH     6156
# Exchange Place    2921
# Hamilton Park     2092
# Sip Ave           1790
# Harborside        1415
# Name: count, dtype: int64

# %%
#bar chart : 5 most popular end station in oct 2019
plt.bar(top5_end.index, top5_end.values)
plt.xticks(rotation=15)
plt.ylabel('total rentals')
plt.title('5 most popular end station in Oct. 2019')
plt.show()

# %%
#look at the gender and usertype to establish a reference point for later analysis
n = df.shape[0]
df['gender'].value_counts()/n
# Out:
# gender
# 1    0.738132
# 2    0.220987
# 0    0.040881
# Name: count, dtype: float64

# %%
#bar chart: user gender
gender_list = ['Male', 'Female', 'Unspecified']
plt.bar(gender_list, df['gender'].value_counts()/n * 100, color = "base_color")
plt.ylabel('Percentage [%]')
plt.title('User gender')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 #bar chart: user gender
#       2 gender_list = ['Male', 'Female', 'Unspecified']
# ----> 3 plt.bar(gender_list, df['gender'].value_counts()/n * 100, color = "base_color")
#       4 plt.ylabel('Percentage [%]')
#       5 plt.title('User gender')
#
# File c:\Users\hoan\miniconda3\Lib\site-packages\matplotlib\pyplot.py:2754, in bar(x, height, width, bottom, align, data, **kwargs)
#    2743 @_copy_docstring_and_deprecators(Axes.bar)
#    2744 def bar(
#    2745     x: float | ArrayLike,
#    (...)
#    2752     **kwargs,
#    2753 ) -> BarContainer:
# -> 2754     return gca().bar(
#    2755         x,
#    2756         height,
#    2757         width=width,
#    2758         bottom=bottom,
#    2759         align=align,
#    2760         **({"data": data} if data is not None else {}),
#    2761         **kwargs,
#    2762     )
#
# File c:\Users\hoan\miniconda3\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File c:\Users\hoan\miniconda3\Lib\site-packages\matplotlib\axes\_axes.py:2484, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2482 linewidth = itertools.cycle(np.atleast_1d(linewidth))
#    2483 hatch = itertools.cycle(np.atleast_1d(hatch))
# -> 2484 color = itertools.chain(itertools.cycle(mcolors.to_rgba_array(color)),
#    2485                         # Fallback if color == "none".
#    2486                         itertools.repeat('none'))
#    2487 if edgecolor is None:
#    2488     edgecolor = itertools.repeat(None)
#
# File c:\Users\hoan\miniconda3\Lib\site-packages\matplotlib\colors.py:489, in to_rgba_array(c, alpha)
#     487         raise e
#     488 if isinstance(c, str):
# --> 489     raise ValueError(f"{c!r} is not a valid color value.")
#     491 if len(c) == 0:
#     492     return np.zeros((0, 4), float)
#
# ValueError: 'base_color' is not a valid color value.

# %%
#exclude unspecified rows and see adjusted percentage
n2 = df.query('gender !=0').shape[0]
(df['gender'].value_counts()/n2)[:2]
# Out:
# gender
# 1    0.769593
# 2    0.230407
# Name: count, dtype: float64

# %%
#bar chart : user gender
gender_list = ['Male', 'Female']
plt.bar(gender_list, (df['gender'].value_counts()/n2)[:2]* 100, color = "base_color")
plt.ylabel('Percentage [%]')
plt.title('User gender')
plt.show()

df['usertype'].value_counts()/n
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 #bar chart : user gender
#       2 gender_list = ['Male', 'Female']
# ----> 3 plt.bar(gender_list, (df['gender'].value_counts()/n2)[:2]* 100, color = "base_color")
#       4 plt.ylabel('Percentage [%]')
#       5 plt.title('User gender')
#
# File c:\Users\hoan\miniconda3\Lib\site-packages\matplotlib\pyplot.py:2754, in bar(x, height, width, bottom, align, data, **kwargs)
#    2743 @_copy_docstring_and_deprecators(Axes.bar)
#    2744 def bar(
#    2745     x: float | ArrayLike,
#    (...)
#    2752     **kwargs,
#    2753 ) -> BarContainer:
# -> 2754     return gca().bar(
#    2755         x,
#    2756         height,
#    2757         width=width,
#    2758         bottom=bottom,
#    2759         align=align,
#    2760         **({"data": data} if data is not None else {}),
#    2761         **kwargs,
#    2762     )
#
# File c:\Users\hoan\miniconda3\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File c:\Users\hoan\miniconda3\Lib\site-packages\matplotlib\axes\_axes.py:2484, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2482 linewidth = itertools.cycle(np.atleast_1d(linewidth))
#    2483 hatch = itertools.cycle(np.atleast_1d(hatch))
# -> 2484 color = itertools.chain(itertools.cycle(mcolors.to_rgba_array(color)),
#    2485                         # Fallback if color == "none".
#    2486                         itertools.repeat('none'))
#    2487 if edgecolor is None:
#    2488     edgecolor = itertools.repeat(None)
#
# File c:\Users\hoan\miniconda3\Lib\site-packages\matplotlib\colors.py:489, in to_rgba_array(c, alpha)
#     487         raise e
#     488 if isinstance(c, str):
# --> 489     raise ValueError(f"{c!r} is not a valid color value.")
#     491 if len(c) == 0:
#     492     return np.zeros((0, 4), float)
#
# ValueError: 'base_color' is not a valid color value.

# %%
#bar chart : user type
usertype_list = ['Subscriber', 'Customer']
plt.bar(usertype_list, (df['usertype'].value_counts()/n)* 100, color = "base_color")
plt.ylabel('Percentage [%]')
plt.title('User Type')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 #bar chart : user type
#       2 usertype_list = ['Subscriber', 'Customer']
# ----> 3 plt.bar(usertype_list, (df['usertype'].value_counts()/n)* 100, color = "base_color")
#       4 plt.ylabel('Percentage [%]')
#       5 plt.title('User Type')
#
# File c:\Users\hoan\miniconda3\Lib\site-packages\matplotlib\pyplot.py:2754, in bar(x, height, width, bottom, align, data, **kwargs)
#    2743 @_copy_docstring_and_deprecators(Axes.bar)
#    2744 def bar(
#    2745     x: float | ArrayLike,
#    (...)
#    2752     **kwargs,
#    2753 ) -> BarContainer:
# -> 2754     return gca().bar(
#    2755         x,
#    2756         height,
#    2757         width=width,
#    2758         bottom=bottom,
#    2759         align=align,
#    2760         **({"data": data} if data is not None else {}),
#    2761         **kwargs,
#    2762     )
#
# File c:\Users\hoan\miniconda3\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File c:\Users\hoan\miniconda3\Lib\site-packages\matplotlib\axes\_axes.py:2484, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2482 linewidth = itertools.cycle(np.atleast_1d(linewidth))
#    2483 hatch = itertools.cycle(np.atleast_1d(hatch))
# -> 2484 color = itertools.chain(itertools.cycle(mcolors.to_rgba_array(color)),
#    2485                         # Fallback if color == "none".
#    2486                         itertools.repeat('none'))
#    2487 if edgecolor is None:
#    2488     edgecolor = itertools.repeat(None)
#
# File c:\Users\hoan\miniconda3\Lib\site-packages\matplotlib\colors.py:489, in to_rgba_array(c, alpha)
#     487         raise e
#     488 if isinstance(c, str):
# --> 489     raise ValueError(f"{c!r} is not a valid color value.")
#     491 if len(c) == 0:
#     492     return np.zeros((0, 4), float)
#
# ValueError: 'base_color' is not a valid color value.
